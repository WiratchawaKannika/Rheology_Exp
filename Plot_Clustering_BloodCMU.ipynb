# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # 🎧Function :Plot

# %%
def plot4group(result_4cluster_, columnName):

    set_sheet = list(set(result_4cluster_[columnName]))
    print(len(set_sheet))
    set_sheet
    #lt.figure(figsize=(12, 8))
    fig = plt.figure(figsize=(12, 8))
    handles_markers = []
    markers_labels = []
    colors_labels = []
    for s in set_sheet:
        result0 = result_4cluster_[result_4cluster_[columnName]==s]
        if s == 0.0:
            colors="red"
            markers="^"
        elif s == 1.0:
            colors="green"
            markers="8"
        elif s == 2.0:
            colors="blue"
            markers="s"
        elif s == 3.0:
            colors="fuchsia"
            markers=">"
        markers_labels.append(markers)
        colors_labels.append(colors)
        print(f"[INFO] Cluster : {s} with Shape ==> {result0.shape[0]}")
        set_code = list(set(result0["Code"]))
        for sc in set_code:
            df_SetCode = result0[result0["Code"]==sc].reset_index(drop=True)    
            x = df_SetCode["x"].tolist()
            y = df_SetCode["y"].tolist()

            #plt.style.use('seaborn')
            plot_handles = plt.plot(x, y, ls=":", marker=markers, markersize=5,lw=2, markerfacecolor="None",color=colors)
            markers_labels.append(s)
            handles_markers.append(handles_markers)
           #plt.plot(x, y, ls=":", marker="8", markersize=4, lw=2, markerfacecolor="None",color=colors)
           #plt.plot(t_x, list_preEff, ls=":", marker="^", markersize=4, lw=2, markerfacecolor="None", label="EffNetB7 Model")
    #         plt.plot(t_x, list_meanM, ls=":", marker="s", markersize=4, lw=2, markerfacecolor="None", label="MSDT Algorithm", color="red")

    plt.xlabel("x", fontsize=16)
    plt.ylabel("y", fontsize=16)
    plt.title('The Plot Of The Clusters: k = 4', fontsize=18)

    import matplotlib.lines as mlines
    red_line = mlines.Line2D([], [], color='red',markersize=5, label='Group 1', linestyle=":", marker="^", markerfacecolor="None")
    green_line = mlines.Line2D([], [], color='green', markersize=5, label='Group 2', linestyle=":", marker="8", markerfacecolor="None")
    blue_line = mlines.Line2D([], [], color='blue', markersize=5, label='Group 3', linestyle=":", marker="s", markerfacecolor="None")
    gold_line = mlines.Line2D([], [], color='fuchsia', markersize=5, label='Group 4', linestyle=":", marker=">", markerfacecolor="None")

    handles = [red_line,green_line, blue_line, gold_line]
    labels = [h.get_label() for h in handles] 

    fig.legend(handles=handles, labels=labels, borderaxespad=5)

    plt.show()
    
    return

# %%
def plot3group(result_4cluster_, columnName):

    set_sheet = list(set(result_4cluster_[columnName]))
    print(len(set_sheet))
    set_sheet
    #lt.figure(figsize=(12, 8))
    fig = plt.figure(figsize=(12, 8))
    handles_markers = []
    markers_labels = []
    colors_labels = []
    for s in set_sheet:
        result0 = result_4cluster_[result_4cluster_[columnName]==s]
        if s == 0.0:
            colors="red"
            markers="^"
        elif s == 1.0:
            colors="green"
            markers="8"
        elif s == 2.0:
            colors="blue"
            markers="s"
        markers_labels.append(markers)
        colors_labels.append(colors)
        print(f"[INFO] Cluster : {s} with Shape ==> {result0.shape[0]}")
        set_code = list(set(result0["Code"]))
        for sc in set_code:
            df_SetCode = result0[result0["Code"]==sc].reset_index(drop=True)    
            x = df_SetCode["x"].tolist()
            y = df_SetCode["y"].tolist()

            #plt.style.use('seaborn')
            plot_handles = plt.plot(x, y, ls=":", marker=markers, markersize=5,lw=2, markerfacecolor="None",color=colors)
            markers_labels.append(s)
            handles_markers.append(handles_markers)
           #plt.plot(x, y, ls=":", marker="8", markersize=4, lw=2, markerfacecolor="None",color=colors)
           #plt.plot(t_x, list_preEff, ls=":", marker="^", markersize=4, lw=2, markerfacecolor="None", label="EffNetB7 Model")
    #         plt.plot(t_x, list_meanM, ls=":", marker="s", markersize=4, lw=2, markerfacecolor="None", label="MSDT Algorithm", color="red")

    plt.xlabel("x", fontsize=16)
    plt.ylabel("y", fontsize=16)
    plt.title('The Plot Of The Clusters: k = 3', fontsize=18)

    import matplotlib.lines as mlines
    red_line = mlines.Line2D([], [], color='red',markersize=5, label='Group 1', linestyle=":", marker="^", markerfacecolor="None")
    green_line = mlines.Line2D([], [], color='green', markersize=5, label='Group 2', linestyle=":", marker="8", markerfacecolor="None")
    blue_line = mlines.Line2D([], [], color='blue', markersize=5, label='Group 3', linestyle=":", marker="s", markerfacecolor="None")
  
    handles = [red_line,green_line, blue_line]
    labels = [h.get_label() for h in handles] 

    fig.legend(handles=handles, labels=labels, borderaxespad=5)

    plt.show()
    
    return

# %%
def plot2group(result_4cluster_, columnName):

    set_sheet = list(set(result_4cluster_[columnName]))
    print(len(set_sheet))
    set_sheet
    #lt.figure(figsize=(12, 8))
    fig = plt.figure(figsize=(12, 8))
    handles_markers = []
    markers_labels = []
    colors_labels = []
    for s in set_sheet:
        result0 = result_4cluster_[result_4cluster_[columnName]==s]
        if s == 0.0:
            colors="red"
            markers="^"
        elif s == 1.0:
            colors="green"
            markers="8"
        markers_labels.append(markers)
        colors_labels.append(colors)
        print(f"[INFO] Cluster : {s} with Shape ==> {result0.shape[0]}")
        set_code = list(set(result0["Code"]))
        for sc in set_code:
            df_SetCode = result0[result0["Code"]==sc].reset_index(drop=True)    
            x = df_SetCode["x"].tolist()
            y = df_SetCode["y"].tolist()

            #plt.style.use('seaborn')
            plot_handles = plt.plot(x, y, ls=":", marker=markers, markersize=5,lw=2, markerfacecolor="None",color=colors)
            markers_labels.append(s)
            handles_markers.append(handles_markers)
           #plt.plot(x, y, ls=":", marker="8", markersize=4, lw=2, markerfacecolor="None",color=colors)
           #plt.plot(t_x, list_preEff, ls=":", marker="^", markersize=4, lw=2, markerfacecolor="None", label="EffNetB7 Model")
    #         plt.plot(t_x, list_meanM, ls=":", marker="s", markersize=4, lw=2, markerfacecolor="None", label="MSDT Algorithm", color="red")

    plt.xlabel("x", fontsize=16)
    plt.ylabel("y", fontsize=16)
    plt.title('The Plot Of The Clusters: k = 2', fontsize=18)

    import matplotlib.lines as mlines
    red_line = mlines.Line2D([], [], color='red',markersize=5, label='Group 1', linestyle=":", marker="^", markerfacecolor="None")
    green_line = mlines.Line2D([], [], color='green', markersize=5, label='Group 2', linestyle=":", marker="8", markerfacecolor="None")
    
  
    handles = [red_line, green_line]
    labels = [h.get_label() for h in handles] 

    fig.legend(handles=handles, labels=labels, borderaxespad=5)

    plt.show()
    
    return

# %% [markdown]
# # #️⃣ K-mean Clustering

# %% [markdown]
# # 📌 By PCA

# %% [markdown]
# > ### K=3

# %%
pcaK3 = pd.read_csv('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_clusterPCA3k.csv')
print(pcaK3.shape)
pcaK3.head()
# Out:
# (129, 14)
#    Unnamed: 0.1  Unnamed: 0                         name   Code          x  \
# 0             0           0  Row statistics of NBL07.csv  NBL07  19.828200
# 1             1           1  Row statistics of NBL07.csv  NBL07   7.900978
# 2             2           2  Row statistics of NBL07.csv  NBL07   5.604837
# 3             3           3   Row statistics of HN38.csv   HN38  19.917410
# 4             4           4   Row statistics of HN38.csv   HN38   7.930730
#
#           y                 sheet       PC1       PC2       PC3       PC4  \
# 0  0.003430                Normal -2.478323  1.595492  1.506165  1.569369
# 1  0.008548                Normal -2.478323  1.595492  1.506165  1.569369
# 2  0.011782                Normal -2.478323  1.595492  1.506165  1.569369
# 3  0.002190  Patients_NoCutSpleen  0.271246  2.184019  0.427708 -0.915504
# 4  0.005455  Patients_NoCutSpleen  0.271246  2.184019  0.427708 -0.915504
#
#         PC5   No.  Clusterk3
# ...

# %%
import matplotlib.pyplot as plt

columnName = "Clusterk3"
plot3group(pcaK3, columnName)
# Out:
# 3
# [INFO] Cluster : 0.0 with Shape ==> 39
# [INFO] Cluster : 1.0 with Shape ==> 42
# [INFO] Cluster : 2.0 with Shape ==> 48

# %%
columnName = "Clusterk3" 
set_sheet = list(set(pcaK3[columnName]))
print(len(set_sheet))
lst_result0 = []
for s in set_sheet:
    print(f"[INFO] The Clusters Group {int(s+1)}")
    result0 = pcaK3[pcaK3[columnName]==s]
    lst_result0.append(result0)
    print(f"Group Spleen ==> ", list(set(result0["sheet"])))
    print('*'*125)
    import seaborn as sns

    pl = sns.countplot(x=result0["sheet"])
    pl.set_title(f"Distribution Of The Clusters : Group {int(s+1)}")
    plt.show()
# Out:
# 3
# [INFO] The Clusters Group 1
# Group Spleen ==>  ['Patients_CutSpleen', 'Patients_NoCutSpleen']
# *****************************************************************************************************************************
# [INFO] The Clusters Group 2
# Group Spleen ==>  ['Patients_NoCutSpleen']
# *****************************************************************************************************************************
# [INFO] The Clusters Group 3
# Group Spleen ==>  ['Normal', 'Patients_CutSpleen']
# *****************************************************************************************************************************

# %%
import matplotlib.pyplot as plt

## Sheet 
set_sheet = list(set(pcaK3['sheet']))
set_cluster = list(set(pcaK3['Clusterk3']))
print(len(set_sheet))
set_sheet
#lt.figure(figsize=(12, 8))
fig = plt.figure(figsize=(12, 8))
handles_markers = []
markers_labels = []
colors_labels = []
for s in set_sheet:
    result0 = pcaK3[pcaK3["sheet"]==s]
    if s == "Patients_NoCutSpleen":
        colors="red"
        markers="8"
    elif s == "Patients_CutSpleen":
        colors="green"
        markers="8"
    elif s == "Normal":
        colors="blue"
        markers="8"
    markers_labels.append(markers)
    colors_labels.append(colors)
    print(f"[INFO] Sheet : {s} with Shape ==> {int(result0.shape[0]/3)} Cases")
    set_code = list(set(result0["Code"]))
    for sc in set_code:
        df_SetCode = result0[result0["Code"]==sc].reset_index(drop=True)    
        x = df_SetCode["x"].tolist()
        y = df_SetCode["y"].tolist()
    
        #plt.style.use('seaborn')
        plot_handles = plt.plot(x, y, ls=":", marker=markers, markersize=15,lw=2, markerfacecolor="None",color=colors)
        markers_labels.append(s)
        handles_markers.append(handles_markers)
print("*"*125)
### Cluster
for c in set_cluster:
    result00 = pcaK3[pcaK3["Clusterk3"]==c]
    if c == 0.0:
        colors_k="red"
        markers_k="s"
    elif c == 1.0:
        colors_k="green"
        markers_k="s"
    elif c == 2.0:
        colors_k="blue"
        markers_k="s"
    print(f"[INFO] Sheet : Cluster Group {int(c+1)} with Shape ==> {int(result00.shape[0]/3)} Cases")
    set_code = list(set(result00["Code"]))
    for sc in set_code:
        df_SetCode = result00[result00["Code"]==sc].reset_index(drop=True)    
        x_k = df_SetCode["x"].tolist()
        y_k = df_SetCode["y"].tolist()
    
        #plt.style.use('seaborn')
        plot_handles = plt.plot(x_k, y_k, ls=":", marker=markers_k, markersize=5,lw=2, markerfacecolor="None",color=colors_k)
       
        
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.title('The Plot Of The Clusters', fontsize=18)

import matplotlib.lines as mlines
red_line = mlines.Line2D([], [], color='red',markersize=5, label='Patients No Cut Spleen', linestyle=":", marker="8", markerfacecolor="None")
green_line = mlines.Line2D([], [], color='green', markersize=5, label='Patients Cut Spleen', linestyle=":", marker="8", markerfacecolor="None")
blue_line = mlines.Line2D([], [], color='blue', markersize=5, label='Normal', linestyle=":", marker="8", markerfacecolor="None")

handles = [red_line,green_line, blue_line]
labels = [h.get_label() for h in handles] 

fig.legend(handles=handles, labels=labels, borderaxespad=5, title="Sheet", fancybox=True)

red_line_k = mlines.Line2D([], [], color='red',markersize=5, label='Group 1', linestyle=":", marker="s", markerfacecolor="None")
green_line_k = mlines.Line2D([], [], color='green', markersize=5, label='Group 2', linestyle=":", marker="s", markerfacecolor="None")
blue_line_k = mlines.Line2D([], [], color='blue', markersize=5, label='Group 3', linestyle=":", marker="s", markerfacecolor="None")

handles_k = [red_line_k,green_line_k, blue_line_k]
labels_k = [h.get_label() for h in handles_k] 

fig.legend(handles=handles_k, labels=labels_k, borderaxespad=12, title="Cluster k-mean", fancybox=True)

plt.show()
# Out:
# 3
# [INFO] Sheet : Normal with Shape ==> 15 Cases
# [INFO] Sheet : Patients_CutSpleen with Shape ==> 12 Cases
# [INFO] Sheet : Patients_NoCutSpleen with Shape ==> 16 Cases
# *****************************************************************************************************************************
# [INFO] Sheet : Cluster Group 1 with Shape ==> 13 Cases
# [INFO] Sheet : Cluster Group 2 with Shape ==> 14 Cases
# [INFO] Sheet : Cluster Group 3 with Shape ==> 16 Cases

# %% [markdown]
# > ### K=4

# %%
import matplotlib.pyplot as plt

pcaK4 = pd.read_csv('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_clusterPCA4k.csv')
print(pcaK4.shape)

columnName = "Clusterk4"
plot4group(pcaK4, columnName)
# Out:
# (129, 14)
# 4
# [INFO] Cluster : 0.0 with Shape ==> 39
# [INFO] Cluster : 1.0 with Shape ==> 45
# [INFO] Cluster : 2.0 with Shape ==> 27
# [INFO] Cluster : 3.0 with Shape ==> 18

# %% [markdown]
# # 📌 By Standardize

# %% [markdown]
# > ## k=2

# %%
import matplotlib.pyplot as plt

K2 = pd.read_csv('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_clusterk2.csv')
print(K2.shape)

columnName = "2_Cluster"
plot2group(K2, columnName)
# Out:
# (129, 33)
# 2
# [INFO] Cluster : 0.0 with Shape ==> 48
# [INFO] Cluster : 1.0 with Shape ==> 81

# %%
columnName = "2_Cluster" 
set_sheet = list(set(K2[columnName]))
print(len(set_sheet))
lst_result0 = []
for s in set_sheet:
    print(f"[INFO] The Clusters Group {int(s+1)}")
    result0 = K2[K2[columnName]==s]
    lst_result0.append(result0)
    print(f"Group Spleen ==> ", list(set(result0["sheet_y"])))
    print('*'*125)
# Out:
# 2
# [INFO] The Clusters Group 1
# Group Spleen ==>  ['Normal', 'Patients_CutSpleen']
# *****************************************************************************************************************************
# [INFO] The Clusters Group 2
# Group Spleen ==>  ['Patients_CutSpleen', 'Patients_NoCutSpleen']
# *****************************************************************************************************************************

# %%
sheet_y = list(set(lst_result0[0]["sheet_y"]))
for y in sheet_y:
    df_y = lst_result0[0][lst_result0[0]["sheet_y"]==y]
    print(f"[INFO]: Group '{y}' ==> {int(df_y.shape[0]/3)} Cases")
    print("*"*125)
# Out:
# [INFO]: Group 'Normal' ==> 15 Cases
# *****************************************************************************************************************************
# [INFO]: Group 'Patients_CutSpleen' ==> 1 Cases
# *****************************************************************************************************************************

# %%
#Plotting countplot of clusters
import seaborn as sns

pl = sns.countplot(x=lst_result0[0]["sheet_y"])
pl.set_title("Distribution Of The Clusters : Group 1")
plt.show()

# %%
#Plotting countplot of clusters
import seaborn as sns

pl = sns.countplot(x=lst_result0[1]["sheet_y"])
pl.set_title("Distribution Of The Clusters : Group 2")
plt.show()

# %% [markdown]
# > ## k=3

# %%
#result_4cluster_.to_csv(('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_cluster.csv'))
result_4cluster_  =pd.read_csv('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_cluster.csv')
print(result_4cluster_.shape)
result_4cluster_.head()

columnName = "3_Cluster"
plot3group(result_4cluster_, columnName)
# Out:
# (129, 32)
# 3
# [INFO] Cluster : 0.0 with Shape ==> 39
# [INFO] Cluster : 1.0 with Shape ==> 48
# [INFO] Cluster : 2.0 with Shape ==> 42

# %%
columnName = "3_Cluster" 
set_sheet = list(set(result_4cluster_[columnName]))
print(len(set_sheet))
lst_result0 = []
for s in set_sheet:
    print(f"[INFO] The Clusters Group {int(s+1)}")
    result0 = result_4cluster_[result_4cluster_[columnName]==s]
    lst_result0.append(result0)
    print(f"Group Spleen ==> ", list(set(result0["sheet"])))
    print('*'*125)
    import seaborn as sns

    pl = sns.countplot(x=result0["sheet"])
    pl.set_title(f"Distribution Of The Clusters : Group {int(s+1)}")
    plt.show()
# Out:
# 3
# [INFO] The Clusters Group 1
# Group Spleen ==>  ['Patients_CutSpleen', 'Patients_NoCutSpleen']
# *****************************************************************************************************************************
# [INFO] The Clusters Group 2
# Group Spleen ==>  ['Normal', 'Patients_CutSpleen']
# *****************************************************************************************************************************
# [INFO] The Clusters Group 3
# Group Spleen ==>  ['Patients_NoCutSpleen']
# *****************************************************************************************************************************

# %%
import matplotlib.pyplot as plt

## Sheet 
set_sheet = list(set(result_4cluster_['sheet']))
set_cluster = list(set(result_4cluster_['3_Cluster']))
print(len(set_sheet))
set_sheet
#lt.figure(figsize=(12, 8))
fig = plt.figure(figsize=(12, 8))
handles_markers = []
markers_labels = []
colors_labels = []
for s in set_sheet:
    result0 = result_4cluster_[result_4cluster_["sheet"]==s]
    if s == "Patients_NoCutSpleen":
        colors="red"
        markers="8"
    elif s == "Patients_CutSpleen":
        colors="green"
        markers="8"
    elif s == "Normal":
        colors="blue"
        markers="8"
    markers_labels.append(markers)
    colors_labels.append(colors)
    print(f"[INFO] Sheet : {s} with Shape ==> {int(result0.shape[0]/3)} Cases")
    set_code = list(set(result0["Code"]))
    for sc in set_code:
        df_SetCode = result0[result0["Code"]==sc].reset_index(drop=True)    
        x = df_SetCode["x"].tolist()
        y = df_SetCode["y"].tolist()
    
        #plt.style.use('seaborn')
        plot_handles = plt.plot(x, y, ls=":", marker=markers, markersize=15,lw=2, markerfacecolor="None",color=colors)
        markers_labels.append(s)
        handles_markers.append(handles_markers)
print("*"*125)
### Cluster
for c in set_cluster:
    result00 = result_4cluster_[result_4cluster_["3_Cluster"]==c]
    if c == 0.0:
        colors_k="red"
        markers_k="s"
    elif c == 1.0:
        colors_k="green"
        markers_k="s"
    elif c == 2.0:
        colors_k="blue"
        markers_k="s"
    print(f"[INFO] Sheet : Cluster Group {int(c+1)} with Shape ==> {int(result00.shape[0]/3)} Cases")
    set_code = list(set(result00["Code"]))
    for sc in set_code:
        df_SetCode = result00[result00["Code"]==sc].reset_index(drop=True)    
        x_k = df_SetCode["x"].tolist()
        y_k = df_SetCode["y"].tolist()
    
        #plt.style.use('seaborn')
        plot_handles = plt.plot(x_k, y_k, ls=":", marker=markers_k, markersize=5,lw=2, markerfacecolor="None",color=colors_k)
       
        
plt.xlabel("x", fontsize=16)
plt.ylabel("y", fontsize=16)
plt.title('The Plot Of The Clusters', fontsize=18)

import matplotlib.lines as mlines
red_line = mlines.Line2D([], [], color='red',markersize=5, label='Patients No Cut Spleen', linestyle=":", marker="8", markerfacecolor="None")
green_line = mlines.Line2D([], [], color='green', markersize=5, label='Patients Cut Spleen', linestyle=":", marker="8", markerfacecolor="None")
blue_line = mlines.Line2D([], [], color='blue', markersize=5, label='Normal', linestyle=":", marker="8", markerfacecolor="None")

handles = [red_line,green_line, blue_line]
labels = [h.get_label() for h in handles] 

fig.legend(handles=handles, labels=labels, borderaxespad=5, title="Sheet", fancybox=True)

red_line_k = mlines.Line2D([], [], color='red',markersize=5, label='Group 1', linestyle=":", marker="s", markerfacecolor="None")
green_line_k = mlines.Line2D([], [], color='green', markersize=5, label='Group 2', linestyle=":", marker="s", markerfacecolor="None")
blue_line_k = mlines.Line2D([], [], color='blue', markersize=5, label='Group 3', linestyle=":", marker="s", markerfacecolor="None")

handles_k = [red_line_k,green_line_k, blue_line_k]
labels_k = [h.get_label() for h in handles_k] 

fig.legend(handles=handles_k, labels=labels_k, borderaxespad=12, title="Cluster k-mean", fancybox=True)

plt.show()
# Out:
# 3
# [INFO] Sheet : Normal with Shape ==> 15 Cases
# [INFO] Sheet : Patients_CutSpleen with Shape ==> 12 Cases
# [INFO] Sheet : Patients_NoCutSpleen with Shape ==> 16 Cases
# *****************************************************************************************************************************
# [INFO] Sheet : Cluster Group 1 with Shape ==> 13 Cases
# [INFO] Sheet : Cluster Group 2 with Shape ==> 16 Cases
# [INFO] Sheet : Cluster Group 3 with Shape ==> 14 Cases

# %% [markdown]
# ### 🧸sklearn.cluster.Birch

# %%
import matplotlib.pyplot as plt

Birchk3 = pd.read_csv('/home/kannika/codes_AI/Rheology_Blood/All_lab_results_Blood_viscosity_BirchCluster.csv')
print(Birchk3.shape)

columnName = "Birchk3"
plot3group(Birchk3, columnName)
# Out:
# (129, 14)
# 3
# [INFO] Cluster : 0.0 with Shape ==> 57
# [INFO] Cluster : 1.0 with Shape ==> 48
# [INFO] Cluster : 2.0 with Shape ==> 24
